# %% [markdown]
# # Data cleaning

# %%
import pandas as pd
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
import re
import string

emoji_pattern = re.compile("["
                        u"\U0001F600-\U0001F64F"  # emoticons
                        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                        u"\U0001F680-\U0001F6FF"  # transport & map symbols
                        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
                        
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    text = emoji_pattern.sub(r'', text)
    return text

# %%
def clean(df):
    text_cleaned = []
    for text in df['text']:
        text_cleaned.append(clean_text(text))
    df['text'] = text_cleaned
    return df

# %%
train = clean(train)
test = clean(test)

# %%
test
# Out:
#        Unnamed: 0                                               text  \
# 0               0   im still really annoyed about what has happened
# 1               1  they say they understand that i need my alone ...
# 2               2  the exhaustion i feel literally causes me to n...
# 3               3  why am i planning to kill myself this world is...
# 4               4  now  months later im just tired but i cant sle...
# ...           ...                                                ...
# 80337       80337  i read in amazement from my small town in the ...
# 80338       80338  note in the past i feel like im a little traum...
# 80339       80339  i had a lot of interviews and sent hundreds of...
# 80340       80340  ive been struggling for the past few years to ...
# 80341       80341  i have  mg worth of pilas  in total if i take ...
#
#             class
# 0         neither
# 1         neither
# 2         neither
# 3      depression
# 4      depression
# ...           ...
# 80337     neither
# 80338  depression
# 80339     suicide
# 80340  depression
# 80341     suicide
#
# [80342 rows x 3 columns]

# %%
train.to_csv('train.csv')
test.to_csv('test.csv')
